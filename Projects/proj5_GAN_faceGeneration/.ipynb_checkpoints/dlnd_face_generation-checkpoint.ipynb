# %% [markdown]
# # Face Generation
# In this project, you'll use generative adversarial networks to generate new images of faces.
# ### Get the Data
# You'll be using two datasets in this project:
# - MNIST
# - CelebA
#
# Since the celebA dataset is complex and you're doing GANs in a project for the first time, we want you to test your neural network on MNIST before CelebA.  Running the GANs on MNIST will allow you to see how well your model trains sooner.
#
# If you're using [FloydHub](https://www.floydhub.com/), set `data_dir` to "/input" and use the [FloydHub data ID](http://docs.floydhub.com/home/using_datasets/) "R5KrjnANiKVhLWAkpXhNBe".

# %%
#data_dir = './data'

# FloydHub - Use with data ID "R5KrjnANiKVhLWAkpXhNBe"
data_dir = '/input'


"""
DON'T MODIFY ANYTHING IN THIS CELL
"""
import helper

helper.download_extract('mnist', data_dir)
helper.download_extract('celeba', data_dir)
# Out:
# Found mnist Data
# Found celeba Data

# %% [markdown]
# ## Explore the Data
# ### MNIST
# As you're aware, the [MNIST](http://yann.lecun.com/exdb/mnist/) dataset contains images of handwritten digits. You can view the first number of examples by changing `show_n_images`.

# %%
show_n_images = 25

"""
DON'T MODIFY ANYTHING IN THIS CELL
"""
# %matplotlib inline
import os
from glob import glob
from matplotlib import pyplot

mnist_images = helper.get_batch(glob(os.path.join(data_dir, 'mnist/*.jpg'))[:show_n_images], 28, 28, 'L')
pyplot.imshow(helper.images_square_grid(mnist_images, 'L'), cmap='gray')

# %% [markdown]
# ### CelebA
# The [CelebFaces Attributes Dataset (CelebA)](http://mmlab.ie.cuhk.edu.hk/projects/CelebA.html) dataset contains over 200,000 celebrity images with annotations.  Since you're going to be generating faces, you won't need the annotations.  You can view the first number of examples by changing `show_n_images`.

# %%
show_n_images = 25

"""
DON'T MODIFY ANYTHING IN THIS CELL
"""
mnist_images = helper.get_batch(glob(os.path.join(data_dir, 'img_align_celeba/*.jpg'))[:show_n_images], 28, 28, 'RGB')
pyplot.imshow(helper.images_square_grid(mnist_images, 'RGB'))

# %% [markdown]
# ## Preprocess the Data
# Since the project's main focus is on building the GANs, we'll preprocess the data for you.  The values of the MNIST and CelebA dataset will be in the range of -0.5 to 0.5 of 28x28 dimensional images.  The CelebA images will be cropped to remove parts of the image that don't include a face, then resized down to 28x28.
#
# The MNIST images are black and white images with a single [color channel](https://en.wikipedia.org/wiki/Channel_(digital_image%29) while the CelebA images have [3 color channels (RGB color channel)](https://en.wikipedia.org/wiki/Channel_(digital_image%29#RGB_Images).
# ## Build the Neural Network
# You'll build the components necessary to build a GANs by implementing the following functions below:
# - `model_inputs`
# - `discriminator`
# - `generator`
# - `model_loss`
# - `model_opt`
# - `train`
#
# ### Check the Version of TensorFlow and Access to GPU
# This will check to make sure you have the correct version of TensorFlow and access to a GPU

# %%
"""
DON'T MODIFY ANYTHING IN THIS CELL
"""
from distutils.version import LooseVersion
import warnings
import tensorflow as tf

# Check TensorFlow Version
assert LooseVersion(tf.__version__) >= LooseVersion('1.0'), 'Please use TensorFlow version 1.0 or newer.  You are using {}'.format(tf.__version__)
print('TensorFlow Version: {}'.format(tf.__version__))

# Check for a GPU
if not tf.test.gpu_device_name():
    warnings.warn('No GPU found. Please use a GPU to train your neural network.')
else:
    print('Default GPU Device: {}'.format(tf.test.gpu_device_name()))
# Out:
# TensorFlow Version: 1.1.0
# Default GPU Device: /gpu:0

# %% [markdown]
# ### Input
# Implement the `model_inputs` function to create TF Placeholders for the Neural Network. It should create the following placeholders:
# - Real input images placeholder with rank 4 using `image_width`, `image_height`, and `image_channels`.
# - Z input placeholder with rank 2 using `z_dim`.
# - Learning rate placeholder with rank 0.
#
# Return the placeholders in the following the tuple (tensor of real input images, tensor of z data)

# %%
import problem_unittests as tests

def model_inputs(image_width, image_height, image_channels, z_dim):
    """
    Create the model inputs
    :param image_width: The input image width
    :param image_height: The input image height
    :param image_channels: The number of image channels
    :param z_dim: The dimension of Z
    :return: Tuple of (tensor of real input images, tensor of z data, learning rate)
    """
    # TODO: Implement Function

    #return None, None, None
    inputs_real = tf.placeholder(tf.float32, (None, image_width, image_height, image_channels), name='inputs_real')
    inputs_z = tf.placeholder(tf.float32, (None, z_dim), name='input_z')
    learning_rate = tf.placeholder(tf.float32, name="learning_rate")
    
    return inputs_real, inputs_z, learning_rate


"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
tests.test_model_inputs(model_inputs)
# Out:
# Tests Passed

# %% [markdown]
# ### Discriminator
# Implement `discriminator` to create a discriminator neural network that discriminates on `images`.  This function should be able to reuse the variabes in the neural network.  Use [`tf.variable_scope`](https://www.tensorflow.org/api_docs/python/tf/variable_scope) with a scope name of "discriminator" to allow the variables to be reused.  The function should return a tuple of (tensor output of the generator, tensor logits of the generator).

# %%
def discriminator(images, reuse=False, alpha=0.2):
    """
    Create the discriminator network
    :param image: Tensor of input image(s)
    :param reuse: Boolean if the weights should be reused
    :return: Tuple of (tensor output of the discriminator, tensor logits of the discriminator)
    """
    # TODO: Implement Function
    with tf.variable_scope('discriminator', reuse=reuse):
        # Input layer is 28x28x3
        x1 = tf.layers.conv2d(images, 64, 5, strides=2, padding='same', 
                              kernel_initializer= tf.random_normal_initializer(stddev=0.02))
        relu1 = tf.maximum(alpha * x1, x1)
        #out: 14x14x64
        
        x2 = tf.layers.conv2d(relu1, 128, 5, strides=2, padding='same', 
                              kernel_initializer= tf.random_normal_initializer(stddev=0.02))
        bn2 = tf.layers.batch_normalization(x2, training=True)
        relu2 = tf.maximum(alpha * bn2, bn2)
        #out: 7x7x128
        
        # follow suggestion, change kernel size from 256 -> 512
        # number of filters (the dimensionality of the output space) gives the ability to learn more different details
        x3 = tf.layers.conv2d(relu2, 512, 5, strides=1, padding='same', 
                              kernel_initializer= tf.random_normal_initializer(stddev=0.02))
        bn3 = tf.layers.batch_normalization(x3, training=True)
        relu3 = tf.maximum(alpha * bn3, bn3)
        #out: 7x7x256

        # Flatten it
        flat = tf.reshape(relu3, (-1, 7*7*512))
        logits = tf.layers.dense(flat, 1)
        out = tf.sigmoid(logits)
        
        return out, logits
    #return None, None


"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
tests.test_discriminator(discriminator, tf)
# Out:
# Tests Passed

# %% [markdown]
# ### Generator
# Implement `generator` to generate an image using `z`. This function should be able to reuse the variabes in the neural network.  Use [`tf.variable_scope`](https://www.tensorflow.org/api_docs/python/tf/variable_scope) with a scope name of "generator" to allow the variables to be reused. The function should return the generated 28 x 28 x `out_channel_dim` images.

# %%
def generator(z, out_channel_dim, is_train=True, alpha=0.2):
    """
    Create the generator network
    :param z: Input z
    :param out_channel_dim: The number of channels in the output image
    :param is_train: Boolean if generator is being used for training
    :return: The tensor output of the generator
    """
    # TODO: Implement Function
    with tf.variable_scope('generator', reuse=not is_train):
        # First fully connected layer
        x1 = tf.layers.dense(z, 7*7*512)
        # Reshape it to start the convolutional stack
        x1 = tf.reshape(x1, (-1, 7, 7, 512))
        bn1 = tf.layers.batch_normalization(x1, training=is_train)
        lrelu1  = tf.maximum(alpha * bn1, bn1)
        # 7x7x512 now
        
        x2 = tf.layers.conv2d_transpose(lrelu1, 256, 5, strides=2, padding='same')
        bn2 = tf.layers.batch_normalization(x2, training=is_train)
        lrelu2 = tf.maximum(alpha * bn2, bn2)
        # 14x14x256 now
        
        x3 = tf.layers.conv2d_transpose(lrelu2, 64, 5, strides=2, padding='same')
        bn3 = tf.layers.batch_normalization(x3, training=is_train)
        lrelu3 = tf.maximum(alpha * bn3, bn3)
        # 28x28x64 now
        
        # Output layer
        # follow suggestion: switch layer1 and layer3 strides, remove the chessboard effect.
        logits = tf.layers.conv2d_transpose(lrelu3, out_channel_dim, 5, strides=1, padding='same')
        # 28x28x5 now
        
        out = tf.tanh(logits)
    
        return out


"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
tests.test_generator(generator, tf)
# Out:
# Tests Passed

# %% [markdown]
# ### Loss
# Implement `model_loss` to build the GANs for training and calculate the loss.  The function should return a tuple of (discriminator loss, generator loss).  Use the following functions you implemented:
# - `discriminator(images, reuse=False)`
# - `generator(z, out_channel_dim, is_train=True)`

# %%
def model_loss(input_real, input_z, out_channel_dim):
    """
    Get the loss for the discriminator and generator
    :param input_real: Images from the real dataset
    :param input_z: Z input
    :param out_channel_dim: The number of channels in the output image
    :return: A tuple of (discriminator loss, generator loss)
    """
    # TODO: Implement Function
    smooth = 0.9
    
    g_model = generator(input_z, out_channel_dim, is_train=True)
    d_model_real, d_logits_real = discriminator(input_real, reuse=False)
    d_model_fake, d_logits_fake = discriminator(g_model, reuse=True)

    d_loss_real = tf.reduce_mean(
        tf.nn.sigmoid_cross_entropy_with_logits(logits=d_logits_real, 
                                                labels=tf.ones_like(d_model_real)*smooth))
    d_loss_fake = tf.reduce_mean(
        tf.nn.sigmoid_cross_entropy_with_logits(logits=d_logits_fake, 
                                                labels=tf.zeros_like(d_model_real)))
    
    g_loss = tf.reduce_mean(
        tf.nn.sigmoid_cross_entropy_with_logits(logits=d_logits_fake, 
                                                labels=tf.ones_like(d_model_fake)*smooth))

    d_loss = d_loss_real + d_loss_fake

    
    return d_loss, g_loss


"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
tests.test_model_loss(model_loss)
# Out:
# Tests Passed

# %% [markdown]
# ### Optimization
# Implement `model_opt` to create the optimization operations for the GANs. Use [`tf.trainable_variables`](https://www.tensorflow.org/api_docs/python/tf/trainable_variables) to get all the trainable variables.  Filter the variables with names that are in the discriminator and generator scope names.  The function should return a tuple of (discriminator training operation, generator training operation).

# %%
def model_opt(d_loss, g_loss, learning_rate, beta1):
    """
    Get optimization operations
    :param d_loss: Discriminator loss Tensor
    :param g_loss: Generator loss Tensor
    :param learning_rate: Learning Rate Placeholder
    :param beta1: The exponential decay rate for the 1st moment in the optimizer
    :return: A tuple of (discriminator training operation, generator training operation)
    """
    # TODO: Implement Function
    # Get weights and bias to update
    t_vars = tf.trainable_variables()
    d_vars = [var for var in t_vars if var.name.startswith('discriminator')]
    g_vars = [var for var in t_vars if var.name.startswith('generator')]

    # Optimize
    with tf.control_dependencies(tf.get_collection(tf.GraphKeys.UPDATE_OPS)):
        d_train_opt = tf.train.AdamOptimizer(learning_rate, beta1=beta1).minimize(d_loss, var_list=d_vars)
        g_train_opt = tf.train.AdamOptimizer(learning_rate, beta1=beta1).minimize(g_loss, var_list=g_vars)
    
    return d_train_opt, g_train_opt

"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
tests.test_model_opt(model_opt, tf)
# Out:
# Tests Passed

# %% [markdown]
# ## Neural Network Training
# ### Show Output
# Use this function to show the current output of the generator during training. It will help you determine how well the GANs is training.

# %%
"""
DON'T MODIFY ANYTHING IN THIS CELL
"""
import numpy as np

def show_generator_output(sess, n_images, input_z, out_channel_dim, image_mode):
    """
    Show example output for the generator
    :param sess: TensorFlow session
    :param n_images: Number of Images to display
    :param input_z: Input Z Tensor
    :param out_channel_dim: The number of channels in the output image
    :param image_mode: The mode to use for images ("RGB" or "L")
    """
    cmap = None if image_mode == 'RGB' else 'gray'
    z_dim = input_z.get_shape().as_list()[-1]
    example_z = np.random.uniform(-1, 1, size=[n_images, z_dim])

    samples = sess.run(
        generator(input_z, out_channel_dim, False),
        feed_dict={input_z: example_z})

    images_grid = helper.images_square_grid(samples, image_mode)
    pyplot.imshow(images_grid, cmap=cmap)
    pyplot.show()

# %% [markdown]
# ### Train
# Implement `train` to build and train the GANs.  Use the following functions you implemented:
# - `model_inputs(image_width, image_height, image_channels, z_dim)`
# - `model_loss(input_real, input_z, out_channel_dim)`
# - `model_opt(d_loss, g_loss, learning_rate, beta1)`
#
# Use the `show_generator_output` to show `generator` output while you train. Running `show_generator_output` for every batch will drastically increase training time and increase the size of the notebook.  It's recommended to print the `generator` output every 100 batches.

# %%
def train(epoch_count, batch_size, z_dim, learning_rate, beta1, get_batches, data_shape, data_image_mode):
    """
    Train the GAN
    :param epoch_count: Number of epochs
    :param batch_size: Batch Size
    :param z_dim: Z dimension
    :param learning_rate: Learning Rate
    :param beta1: The exponential decay rate for the 1st moment in the optimizer
    :param get_batches: Function to get batches
    :param data_shape: Shape of the data
    :param data_image_mode: The image mode to use for images ("RGB" or "L")
    """
    # TODO: Build Model
    # Set the image width, height, and image channels
    _, image_width, image_height, image_channels = data_shape
    
    #model_inputs(image_width, image_height, image_channels, z_dim)
    # -> return inputs_real, inputs_z, learning_rate
    input_real, input_z, _ = model_inputs(image_width, image_height, image_channels, z_dim)
    
    d_loss, g_loss = model_loss(input_real, input_z, image_channels)
    d_opt, g_opt = model_opt(d_loss, g_loss, learning_rate, beta1)
    
    samples, losses = [], []
    steps = 0
    
    #saver = tf.train.Saver()

    with tf.Session() as sess:
        sess.run(tf.global_variables_initializer())
        for epoch_i in range(epoch_count):
            for batch_images in get_batches(batch_size):
                # TODO: Train Model
                steps += 1

                # Multiply batch_images by 2since the dataset ranges from -0.5 to 0.5
                #images = batch_images * 2.0 # incorrect
                batch_images *= 2
                
                # Sample random noise for G
                batch_z = np.random.uniform(-1, 1, size=(batch_size, z_dim))

                # Run optimizers
                _ = sess.run(d_opt, feed_dict={input_real: batch_images, input_z: batch_z})
                _ = sess.run(g_opt, feed_dict={input_z: batch_z, input_real: batch_images})
                
    
                # every 20 steps PRINT
                if steps % 20 == 0:
                    # At the end of each epoch, get the losses and print them out
                    train_loss_d = d_loss.eval({input_z: batch_z, input_real: batch_images})
                    train_loss_g = g_loss.eval({input_z: batch_z})

                    print("Epoch {}/{}...".format(epoch_i+1, epochs),
                          "Discriminator Loss: {:.4f}...".format(train_loss_d),
                          "Generator Loss: {:.4f}".format(train_loss_g))
                    # Save losses to view after training
                    #losses.append((train_loss_d, train_loss_g))
                
                # show image every 100 step
                if steps % 100 == 0:
                    show_generator_output(sess, 25, input_z, image_channels, data_image_mode)

        #saver.save(sess, './checkpoints/generator.ckpt')

# %% [markdown]
# ### MNIST
# Test your GANs architecture on MNIST.  After 2 epochs, the GANs should be able to generate images that look like handwritten digits.  Make sure the loss of the generator is lower than the loss of the discriminator or close to 0.

# %%
batch_size = 64 # GANs sometimes a smaller batch size works better
z_dim = 100
learning_rate = 0.0005 # change from 0.0001 -> 0.005
beta1 = 0.4


"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
epochs = 2

mnist_dataset = helper.Dataset('mnist', glob(os.path.join(data_dir, 'mnist/*.jpg')))
with tf.Graph().as_default():
    train(epochs, batch_size, z_dim, learning_rate, beta1, mnist_dataset.get_batches,
          mnist_dataset.shape, mnist_dataset.image_mode)
# Out:
# Epoch 1/2... Discriminator Loss: 1.7871... Generator Loss: 7.4540
# Epoch 1/2... Discriminator Loss: 0.4966... Generator Loss: 9.8879
# Epoch 1/2... Discriminator Loss: 1.3830... Generator Loss: 6.3550
# Epoch 1/2... Discriminator Loss: 1.9306... Generator Loss: 1.2683
# Epoch 1/2... Discriminator Loss: 2.5062... Generator Loss: 0.4602
# Epoch 1/2... Discriminator Loss: 1.6157... Generator Loss: 0.5379
# Epoch 1/2... Discriminator Loss: 1.5988... Generator Loss: 0.6614
# Epoch 1/2... Discriminator Loss: 2.1367... Generator Loss: 0.4112
# Epoch 1/2... Discriminator Loss: 1.9131... Generator Loss: 2.2749
# Epoch 1/2... Discriminator Loss: 1.9523... Generator Loss: 2.4771
# Epoch 1/2... Discriminator Loss: 1.7525... Generator Loss: 2.3283
# Epoch 1/2... Discriminator Loss: 1.7684... Generator Loss: 0.4719
# Epoch 1/2... Discriminator Loss: 1.3884... Generator Loss: 0.7522
# Epoch 1/2... Discriminator Loss: 1.2943... Generator Loss: 0.7253
# Epoch 1/2... Discriminator Loss: 1.6124... Generator Loss: 1.7834
# Epoch 1/2... Discriminator Loss: 1.4586... Generator Loss: 1.8339
# Epoch 1/2... Discriminator Loss: 1.5014... Generator Loss: 1.4951
# Epoch 1/2... Discriminator Loss: 1.5065... Generator Loss: 1.8757
# Epoch 1/2... Discriminator Loss: 1.2961... Generator Loss: 1.2625
# Epoch 1/2... Discriminator Loss: 1.2394... Generator Loss: 1.1941
# Epoch 1/2... Discriminator Loss: 1.1162... Generator Loss: 0.9929
# Epoch 1/2... Discriminator Loss: 1.1811... Generator Loss: 0.9498
# Epoch 1/2... Discriminator Loss: 1.4285... Generator Loss: 0.6017
# Epoch 1/2... Discriminator Loss: 1.2927... Generator Loss: 0.7573
# Epoch 1/2... Discriminator Loss: 1.5538... Generator Loss: 2.5913
# Epoch 1/2... Discriminator Loss: 1.3514... Generator Loss: 2.0814
# Epoch 1/2... Discriminator Loss: 1.9094... Generator Loss: 0.4205
# Epoch 1/2... Discriminator Loss: 1.4475... Generator Loss: 0.6233
# Epoch 1/2... Discriminator Loss: 1.7867... Generator Loss: 0.5986
# Epoch 1/2... Discriminator Loss: 1.5470... Generator Loss: 0.7232
# Epoch 1/2... Discriminator Loss: 1.0082... Generator Loss: 2.0895
# Epoch 1/2... Discriminator Loss: 1.5748... Generator Loss: 0.5090
# Epoch 1/2... Discriminator Loss: 1.5869... Generator Loss: 0.5702
# Epoch 1/2... Discriminator Loss: 0.8161... Generator Loss: 2.0644
# Epoch 1/2... Discriminator Loss: 1.4679... Generator Loss: 1.3723
# Epoch 1/2... Discriminator Loss: 1.2806... Generator Loss: 0.9823
# Epoch 1/2... Discriminator Loss: 1.3136... Generator Loss: 0.7303
# Epoch 1/2... Discriminator Loss: 1.5274... Generator Loss: 1.7819
# Epoch 1/2... Discriminator Loss: 1.2321... Generator Loss: 0.7679
# Epoch 1/2... Discriminator Loss: 1.2031... Generator Loss: 0.8541
# Epoch 1/2... Discriminator Loss: 1.3065... Generator Loss: 1.3686
# Epoch 1/2... Discriminator Loss: 2.1081... Generator Loss: 2.4614
# Epoch 1/2... Discriminator Loss: 1.1339... Generator Loss: 1.2233
# Epoch 1/2... Discriminator Loss: 1.4672... Generator Loss: 0.5690
# Epoch 1/2... Discriminator Loss: 1.3161... Generator Loss: 1.2581
# Epoch 1/2... Discriminator Loss: 1.5953... Generator Loss: 0.6098
# Epoch 2/2... Discriminator Loss: 1.5954... Generator Loss: 0.5014
# Epoch 2/2... Discriminator Loss: 1.0962... Generator Loss: 0.9051
# Epoch 2/2... Discriminator Loss: 1.3251... Generator Loss: 1.7391
# Epoch 2/2... Discriminator Loss: 1.6020... Generator Loss: 0.5157
# Epoch 2/2... Discriminator Loss: 1.6156... Generator Loss: 0.5113
# Epoch 2/2... Discriminator Loss: 1.2121... Generator Loss: 0.9202
# Epoch 2/2... Discriminator Loss: 1.3459... Generator Loss: 1.5986
# Epoch 2/2... Discriminator Loss: 3.4020... Generator Loss: 3.9000
# Epoch 2/2... Discriminator Loss: 1.2808... Generator Loss: 1.2233
# Epoch 2/2... Discriminator Loss: 1.2813... Generator Loss: 1.4133
# Epoch 2/2... Discriminator Loss: 1.0496... Generator Loss: 1.0758
# Epoch 2/2... Discriminator Loss: 1.7560... Generator Loss: 0.4749
# Epoch 2/2... Discriminator Loss: 1.2398... Generator Loss: 0.8179
# Epoch 2/2... Discriminator Loss: 1.2584... Generator Loss: 0.7475
# Epoch 2/2... Discriminator Loss: 1.2555... Generator Loss: 0.6573
# Epoch 2/2... Discriminator Loss: 1.2151... Generator Loss: 1.4624
# Epoch 2/2... Discriminator Loss: 1.8214... Generator Loss: 2.3058
# Epoch 2/2... Discriminator Loss: 1.2537... Generator Loss: 1.4562
# Epoch 2/2... Discriminator Loss: 1.1778... Generator Loss: 0.8478
# Epoch 2/2... Discriminator Loss: 1.1947... Generator Loss: 0.7581
# Epoch 2/2... Discriminator Loss: 1.4475... Generator Loss: 2.0572
# Epoch 2/2... Discriminator Loss: 1.0187... Generator Loss: 0.9236
# Epoch 2/2... Discriminator Loss: 0.9866... Generator Loss: 1.3147
# Epoch 2/2... Discriminator Loss: 1.1846... Generator Loss: 1.1551
# Epoch 2/2... Discriminator Loss: 1.4063... Generator Loss: 1.7431
# Epoch 2/2... Discriminator Loss: 1.4252... Generator Loss: 0.6435
# Epoch 2/2... Discriminator Loss: 1.2719... Generator Loss: 0.6948
# Epoch 2/2... Discriminator Loss: 1.5798... Generator Loss: 2.3630
# Epoch 2/2... Discriminator Loss: 1.1836... Generator Loss: 1.3625
# Epoch 2/2... Discriminator Loss: 1.1144... Generator Loss: 0.7869
# Epoch 2/2... Discriminator Loss: 1.9571... Generator Loss: 0.4028
# Epoch 2/2... Discriminator Loss: 1.2003... Generator Loss: 0.9295
# Epoch 2/2... Discriminator Loss: 1.5800... Generator Loss: 2.4615
# Epoch 2/2... Discriminator Loss: 0.9021... Generator Loss: 1.5118
# Epoch 2/2... Discriminator Loss: 1.4954... Generator Loss: 0.5719
# Epoch 2/2... Discriminator Loss: 1.1212... Generator Loss: 0.8251
# Epoch 2/2... Discriminator Loss: 1.0720... Generator Loss: 0.9272
# Epoch 2/2... Discriminator Loss: 1.0703... Generator Loss: 0.9036
# Epoch 2/2... Discriminator Loss: 1.5190... Generator Loss: 0.5313
# Epoch 2/2... Discriminator Loss: 1.0958... Generator Loss: 1.0274
# Epoch 2/2... Discriminator Loss: 1.1377... Generator Loss: 1.3018
# Epoch 2/2... Discriminator Loss: 1.4867... Generator Loss: 2.1856
# Epoch 2/2... Discriminator Loss: 1.4491... Generator Loss: 1.6829
# Epoch 2/2... Discriminator Loss: 1.0373... Generator Loss: 1.2179
# Epoch 2/2... Discriminator Loss: 1.1349... Generator Loss: 0.8748
# Epoch 2/2... Discriminator Loss: 1.0581... Generator Loss: 1.1382
# Epoch 2/2... Discriminator Loss: 1.6413... Generator Loss: 0.5382

# %% [markdown]
# ### CelebA
# Run your GANs on CelebA.  It will take around 20 minutes on the average GPU to run one epoch.  You can run the whole epoch or stop when it starts to generate realistic faces.

# %%
batch_size = 64
z_dim = 100
learning_rate = 0.0005
beta1 = 0.5


"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
epochs = 1

celeba_dataset = helper.Dataset('celeba', glob(os.path.join(data_dir, 'img_align_celeba/*.jpg')))
with tf.Graph().as_default():
    train(epochs, batch_size, z_dim, learning_rate, beta1, celeba_dataset.get_batches,
          celeba_dataset.shape, celeba_dataset.image_mode)
# Out:
# Epoch 1/1... Discriminator Loss: 0.5722... Generator Loss: 35.6218
# Epoch 1/1... Discriminator Loss: 2.8868... Generator Loss: 0.7423
# Epoch 1/1... Discriminator Loss: 0.8483... Generator Loss: 3.7198
# Epoch 1/1... Discriminator Loss: 1.5894... Generator Loss: 0.7248
# Epoch 1/1... Discriminator Loss: 0.5259... Generator Loss: 2.4947
# Epoch 1/1... Discriminator Loss: 4.1915... Generator Loss: 10.1216
# Epoch 1/1... Discriminator Loss: 0.6341... Generator Loss: 1.8022
# Epoch 1/1... Discriminator Loss: 1.6706... Generator Loss: 0.7388
# Epoch 1/1... Discriminator Loss: 1.2254... Generator Loss: 1.1340
# Epoch 1/1... Discriminator Loss: 2.5371... Generator Loss: 0.3924
# Epoch 1/1... Discriminator Loss: 2.1029... Generator Loss: 2.8524
# Epoch 1/1... Discriminator Loss: 1.3485... Generator Loss: 0.5860
# Epoch 1/1... Discriminator Loss: 6.3748... Generator Loss: 6.9977
# Epoch 1/1... Discriminator Loss: 1.3585... Generator Loss: 0.6357
# Epoch 1/1... Discriminator Loss: 0.6002... Generator Loss: 2.8310
# Epoch 1/1... Discriminator Loss: 1.3554... Generator Loss: 0.7231
# Epoch 1/1... Discriminator Loss: 1.3395... Generator Loss: 0.7137
# Epoch 1/1... Discriminator Loss: 1.5064... Generator Loss: 1.4603
# Epoch 1/1... Discriminator Loss: 1.0573... Generator Loss: 1.0356
# Epoch 1/1... Discriminator Loss: 2.5213... Generator Loss: 4.0844
# Epoch 1/1... Discriminator Loss: 0.9652... Generator Loss: 0.9709
# Epoch 1/1... Discriminator Loss: 1.5184... Generator Loss: 0.7928
# Epoch 1/1... Discriminator Loss: 1.7026... Generator Loss: 2.2475
# Epoch 1/1... Discriminator Loss: 0.9705... Generator Loss: 1.0584
# Epoch 1/1... Discriminator Loss: 1.3544... Generator Loss: 0.7650
# Epoch 1/1... Discriminator Loss: 1.0770... Generator Loss: 0.7769
# Epoch 1/1... Discriminator Loss: 1.3647... Generator Loss: 0.6372
# Epoch 1/1... Discriminator Loss: 1.4188... Generator Loss: 1.8022
# Epoch 1/1... Discriminator Loss: 1.3706... Generator Loss: 1.0014
# Epoch 1/1... Discriminator Loss: 1.1185... Generator Loss: 2.7285
# Epoch 1/1... Discriminator Loss: 1.2402... Generator Loss: 1.0019
# Epoch 1/1... Discriminator Loss: 1.2840... Generator Loss: 0.9032
# Epoch 1/1... Discriminator Loss: 1.3177... Generator Loss: 0.6033
# Epoch 1/1... Discriminator Loss: 2.8121... Generator Loss: 0.3785
# Epoch 1/1... Discriminator Loss: 1.2253... Generator Loss: 0.9665
# Epoch 1/1... Discriminator Loss: 1.3686... Generator Loss: 1.3791
# Epoch 1/1... Discriminator Loss: 2.1226... Generator Loss: 2.2976
# Epoch 1/1... Discriminator Loss: 1.5641... Generator Loss: 1.7612
# Epoch 1/1... Discriminator Loss: 1.8908... Generator Loss: 2.0519
# Epoch 1/1... Discriminator Loss: 1.0289... Generator Loss: 2.4257
# Epoch 1/1... Discriminator Loss: 2.9573... Generator Loss: 3.7999
# Epoch 1/1... Discriminator Loss: 1.9235... Generator Loss: 2.0655
# Epoch 1/1... Discriminator Loss: 1.5871... Generator Loss: 1.4424
# Epoch 1/1... Discriminator Loss: 1.3354... Generator Loss: 1.1282
# Epoch 1/1... Discriminator Loss: 1.4550... Generator Loss: 0.7209
# Epoch 1/1... Discriminator Loss: 1.5560... Generator Loss: 1.2817
# Epoch 1/1... Discriminator Loss: 1.0700... Generator Loss: 1.4892
# Epoch 1/1... Discriminator Loss: 0.9530... Generator Loss: 1.3291
# Epoch 1/1... Discriminator Loss: 1.2703... Generator Loss: 1.1748
# Epoch 1/1... Discriminator Loss: 1.2940... Generator Loss: 0.6906
# Epoch 1/1... Discriminator Loss: 1.2372... Generator Loss: 0.6672
# Epoch 1/1... Discriminator Loss: 1.5769... Generator Loss: 0.6136
# Epoch 1/1... Discriminator Loss: 1.4067... Generator Loss: 0.7465
# Epoch 1/1... Discriminator Loss: 1.4228... Generator Loss: 0.7045
# Epoch 1/1... Discriminator Loss: 1.4155... Generator Loss: 0.8075
# Epoch 1/1... Discriminator Loss: 1.4962... Generator Loss: 1.0264
# Epoch 1/1... Discriminator Loss: 1.5082... Generator Loss: 0.9509
# Epoch 1/1... Discriminator Loss: 1.3159... Generator Loss: 0.7941
# Epoch 1/1... Discriminator Loss: 1.3585... Generator Loss: 0.8843
# Epoch 1/1... Discriminator Loss: 1.4478... Generator Loss: 0.7581
# Epoch 1/1... Discriminator Loss: 1.3283... Generator Loss: 0.7617
# Epoch 1/1... Discriminator Loss: 1.4954... Generator Loss: 0.8110
# Epoch 1/1... Discriminator Loss: 1.1542... Generator Loss: 1.0943
# Epoch 1/1... Discriminator Loss: 1.4151... Generator Loss: 0.6531
# Epoch 1/1... Discriminator Loss: 1.3049... Generator Loss: 1.0006
# Epoch 1/1... Discriminator Loss: 1.3452... Generator Loss: 0.7659
# Epoch 1/1... Discriminator Loss: 1.3636... Generator Loss: 0.9522
# Epoch 1/1... Discriminator Loss: 1.2135... Generator Loss: 1.1432
# Epoch 1/1... Discriminator Loss: 1.4562... Generator Loss: 0.7106
# Epoch 1/1... Discriminator Loss: 1.1453... Generator Loss: 0.7330
# Epoch 1/1... Discriminator Loss: 1.3259... Generator Loss: 0.9130
# Epoch 1/1... Discriminator Loss: 1.3152... Generator Loss: 1.4638
# Epoch 1/1... Discriminator Loss: 1.1182... Generator Loss: 1.0840
# Epoch 1/1... Discriminator Loss: 1.8558... Generator Loss: 0.5052
# Epoch 1/1... Discriminator Loss: 1.3159... Generator Loss: 0.7846
# Epoch 1/1... Discriminator Loss: 1.2085... Generator Loss: 0.9075
# Epoch 1/1... Discriminator Loss: 1.3636... Generator Loss: 1.0308
# Epoch 1/1... Discriminator Loss: 1.4228... Generator Loss: 0.8095
# Epoch 1/1... Discriminator Loss: 1.3018... Generator Loss: 0.8733
# Epoch 1/1... Discriminator Loss: 1.3551... Generator Loss: 1.2380
# Epoch 1/1... Discriminator Loss: 1.4049... Generator Loss: 0.7154
# Epoch 1/1... Discriminator Loss: 1.3103... Generator Loss: 0.8041
# Epoch 1/1... Discriminator Loss: 1.2377... Generator Loss: 2.0110
# Epoch 1/1... Discriminator Loss: 1.7632... Generator Loss: 2.0551
# Epoch 1/1... Discriminator Loss: 1.2382... Generator Loss: 1.0678
# Epoch 1/1... Discriminator Loss: 1.2245... Generator Loss: 1.2803
# Epoch 1/1... Discriminator Loss: 1.4528... Generator Loss: 0.9106
# Epoch 1/1... Discriminator Loss: 1.5674... Generator Loss: 0.5007
# Epoch 1/1... Discriminator Loss: 1.4428... Generator Loss: 1.2808
# Epoch 1/1... Discriminator Loss: 1.1764... Generator Loss: 0.8187
# Epoch 1/1... Discriminator Loss: 1.4591... Generator Loss: 1.2341
# Epoch 1/1... Discriminator Loss: 1.7281... Generator Loss: 1.8500
# Epoch 1/1... Discriminator Loss: 1.5465... Generator Loss: 1.1386
# Epoch 1/1... Discriminator Loss: 1.4666... Generator Loss: 0.9612
# Epoch 1/1... Discriminator Loss: 1.0513... Generator Loss: 1.1147
# Epoch 1/1... Discriminator Loss: 1.2321... Generator Loss: 0.6386
# Epoch 1/1... Discriminator Loss: 1.3852... Generator Loss: 0.9005
# Epoch 1/1... Discriminator Loss: 1.5283... Generator Loss: 0.6031
# Epoch 1/1... Discriminator Loss: 1.4497... Generator Loss: 0.8903
# Epoch 1/1... Discriminator Loss: 1.4848... Generator Loss: 1.4557
# Epoch 1/1... Discriminator Loss: 1.2678... Generator Loss: 1.2180
# Epoch 1/1... Discriminator Loss: 1.4617... Generator Loss: 0.5900
# Epoch 1/1... Discriminator Loss: 1.2228... Generator Loss: 1.5470
# Epoch 1/1... Discriminator Loss: 1.4168... Generator Loss: 1.0108
# Epoch 1/1... Discriminator Loss: 1.3175... Generator Loss: 0.7397
# Epoch 1/1... Discriminator Loss: 1.3260... Generator Loss: 1.0866
# Epoch 1/1... Discriminator Loss: 1.0482... Generator Loss: 0.9265
# Epoch 1/1... Discriminator Loss: 1.7051... Generator Loss: 1.5446
# Epoch 1/1... Discriminator Loss: 1.4104... Generator Loss: 0.6201
# Epoch 1/1... Discriminator Loss: 1.4900... Generator Loss: 0.5434
# Epoch 1/1... Discriminator Loss: 1.1429... Generator Loss: 1.1949
# Epoch 1/1... Discriminator Loss: 1.2264... Generator Loss: 0.7773
# Epoch 1/1... Discriminator Loss: 1.3775... Generator Loss: 1.0346
# Epoch 1/1... Discriminator Loss: 1.2800... Generator Loss: 0.7338
# Epoch 1/1... Discriminator Loss: 1.3369... Generator Loss: 0.8609
# Epoch 1/1... Discriminator Loss: 1.4363... Generator Loss: 1.0175
# Epoch 1/1... Discriminator Loss: 1.4291... Generator Loss: 0.7868
# Epoch 1/1... Discriminator Loss: 1.2740... Generator Loss: 0.8925
# Epoch 1/1... Discriminator Loss: 1.4519... Generator Loss: 0.9330
# Epoch 1/1... Discriminator Loss: 1.4574... Generator Loss: 0.9525
# Epoch 1/1... Discriminator Loss: 0.7994... Generator Loss: 1.3889
# Epoch 1/1... Discriminator Loss: 1.2796... Generator Loss: 0.7644
# Epoch 1/1... Discriminator Loss: 1.7588... Generator Loss: 1.9191
# Epoch 1/1... Discriminator Loss: 1.3842... Generator Loss: 1.0031
# Epoch 1/1... Discriminator Loss: 1.4431... Generator Loss: 0.6545
# Epoch 1/1... Discriminator Loss: 1.1122... Generator Loss: 1.2160
# Epoch 1/1... Discriminator Loss: 1.3417... Generator Loss: 0.8021
# Epoch 1/1... Discriminator Loss: 1.3639... Generator Loss: 0.8272
# Epoch 1/1... Discriminator Loss: 1.4906... Generator Loss: 1.2909
# Epoch 1/1... Discriminator Loss: 0.9882... Generator Loss: 1.0738
# Epoch 1/1... Discriminator Loss: 1.6318... Generator Loss: 1.3232
# Epoch 1/1... Discriminator Loss: 1.2790... Generator Loss: 1.2573
# Epoch 1/1... Discriminator Loss: 1.3068... Generator Loss: 1.0468
# Epoch 1/1... Discriminator Loss: 1.3186... Generator Loss: 1.1957
# Epoch 1/1... Discriminator Loss: 1.3810... Generator Loss: 0.6934
# Epoch 1/1... Discriminator Loss: 1.4378... Generator Loss: 0.5702
# Epoch 1/1... Discriminator Loss: 1.1185... Generator Loss: 0.9101
# Epoch 1/1... Discriminator Loss: 1.4045... Generator Loss: 0.5801
# Epoch 1/1... Discriminator Loss: 1.3541... Generator Loss: 0.7917
# Epoch 1/1... Discriminator Loss: 1.2539... Generator Loss: 0.7847
# Epoch 1/1... Discriminator Loss: 1.3158... Generator Loss: 0.7142
# Epoch 1/1... Discriminator Loss: 1.3822... Generator Loss: 0.7598
# Epoch 1/1... Discriminator Loss: 1.5223... Generator Loss: 0.5023
# Epoch 1/1... Discriminator Loss: 1.3264... Generator Loss: 0.8505
# Epoch 1/1... Discriminator Loss: 0.8222... Generator Loss: 1.5650
# Epoch 1/1... Discriminator Loss: 1.2109... Generator Loss: 0.8758
# Epoch 1/1... Discriminator Loss: 0.9425... Generator Loss: 1.2500
# Epoch 1/1... Discriminator Loss: 1.4685... Generator Loss: 0.5629
# Epoch 1/1... Discriminator Loss: 1.5268... Generator Loss: 0.5771
# Epoch 1/1... Discriminator Loss: 1.4061... Generator Loss: 0.7361
# Epoch 1/1... Discriminator Loss: 1.1456... Generator Loss: 1.4202
# Epoch 1/1... Discriminator Loss: 1.1560... Generator Loss: 1.0333
# Epoch 1/1... Discriminator Loss: 1.2725... Generator Loss: 0.9279
# Epoch 1/1... Discriminator Loss: 1.0950... Generator Loss: 0.9125
# Epoch 1/1... Discriminator Loss: 1.2618... Generator Loss: 1.0047
# Epoch 1/1... Discriminator Loss: 1.2612... Generator Loss: 0.7611
# Epoch 1/1... Discriminator Loss: 1.0996... Generator Loss: 1.2751

# %% [markdown]
# ### Submitting This Project
# When submitting this project, make sure to run all the cells before saving the notebook. Save the notebook file as "dlnd_face_generation.ipynb" and save it as a HTML file under "File" -> "Download as". Include the "helper.py" and "problem_unittests.py" files in your submission.
